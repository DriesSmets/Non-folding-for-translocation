# %% [markdown]
# # Refolding with Circular Dichroism (222 nm)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import peakutils
from scipy.signal import savgol_filter
import scipy.signal as signal
import pandas as pd
import statistics

# %%
spectra = np.genfromtxt('PpiB folding.txt').T
spectra.shape
# Out:
# (4, 4501)

# %%
#plot raw data of PpiB refolding at 4°C
x1=spectra[0]
y1=spectra[1]
plt.xlabel('Time(min)')
plt.ylabel('delta ellipticity')
plt.plot (x1,y1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Fitting raw data with smoothed curve from Butterworth filter
N  = 3    # Filter order
Wn = 0.005 # Cutoff frequency
B, A = signal.butter(N, Wn, output='ba')
smooth_data1 = signal.filtfilt(B,A,y1)


fig,ax1=plt.subplots()
ax1.plot(x1,y1)
ax1.plot(x1,smooth_data1)
plt.xlabel('Time(min)')
plt.ylabel('delta ellipticity')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.savetxt('PpiB folding 1', smooth_data1)
