# %%
# %matplotlib inline
import statistics

import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as signal

# %%
# update to ppia
spectra = np.genfromtxt('Thermal_PpiB_208.txt').T
spectra.shape
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-01e79d4ef75d> in <module>
#       1 # update to ppia
# ----> 2 spectra = np.genfromtxt('Thermal_PpiB_208.txt').T
#       3 spectra.shape
#       4
#
# ~\Miniconda3\envs\py36Global\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1747             fname = os_fspath(fname)
#    1748         if isinstance(fname, str):
# -> 1749             fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1750             fid_ctx = contextlib.closing(fid)
#    1751         else:
#
# ~\Miniconda3\envs\py36Global\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# ~\Miniconda3\envs\py36Global\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: Thermal_PpiB_208.txt not found.

# %%
#plot all raw data
x=spectra[0]
y=spectra[1]
plt.xlabel('Temperature')
plt.ylabel('mmdeg')
plt.plot(*spectra)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b5e8c186013f> in <module>
#       1 #plot all raw data
# ----> 2 x=spectra[0]
#       3 y=spectra[1]
#       4 plt.xlabel('Temperature')
#       5 plt.ylabel('mmdeg')
#
# NameError: name 'spectra' is not defined

# %%
#plot data first sample
x1=spectra[0]
y1=spectra[1]
# Design the Buterworth filter
N  = 3    # Filter order
Wn = 0.1 # Cutoff frequency
B, A = signal.butter(N, Wn, output='ba')
smooth_data1 = signal.filtfilt(B,A,y1)

yprime1 = np.diff(smooth_data1)
xprime1 = x[:-1]+0.5*np.diff(x1)
fig,(ax1,ax2)=plt.subplots(2)
ax1.plot(x1,y1)
ax1.plot(x1,smooth_data1)
ax2.plot(xprime1,yprime1)
#plt.plot(x,y)
plt.xlabel('Temperature')
plt.ylabel('mmdeg')

plt.show()
np.argmax(yprime1)
xprime1[np.argmax(yprime1)]
# Out:
# <img src="data:image/png;base64,..." width="640">
# 14.67

# %%
#plot data second sample
x2=spectra[2]
y2=spectra[3]
# Design the Buterworth filter
N  = 3    # Filter order
Wn = 0.1 # Cutoff frequency
B, A = signal.butter(N, Wn, output='ba')
smooth_data2 = signal.filtfilt(B,A,y2)

yprime2 = np.diff(smooth_data2)
xprime2 = x[:-1]+0.5*np.diff(x2)
fig,(ax1,ax2)=plt.subplots(2)
#ax1.plot(x2,y2)
ax1.plot(x2,smooth_data2)
ax2.plot(xprime2,yprime2)
#plt.plot(x,y)
plt.xlabel('Temperature')
plt.ylabel('mdeg')

plt.show()
np.argmax(yprime2)
xprime2[np.argmax(yprime2)]
# Out:
# <img src="data:image/png;base64,..." width="640">
# 85.37

# %%
#plot data third sample
x3=spectra[4]
y3=spectra[5]
# Design the Buterworth filter
N  = 3    # Filter order
Wn = 0.1 # Cutoff frequency
B, A = signal.butter(N, Wn, output='ba')
smooth_data3 = signal.filtfilt(B,A,y3)

yprime3 = np.diff(smooth_data3)
xprime3 = x[:-1]+0.5*np.diff(x)
fig,(ax1,ax2)=plt.subplots(2)
ax1.plot(x3,y3)
ax1.plot(x3,smooth_data3)
ax2.plot(xprime3,yprime3)
#plt.plot(x,y)
plt.xlabel('Temperature')
plt.ylabel('mmdeg')

plt.show()
np.argmax(yprime3)
xprime3[np.argmax(yprime3)]
# Out:
# <img src="data:image/png;base64,..." width="640">
# 89.85

# %%
list=[xprime1[np.argmin(yprime1)],xprime2[np.argmin(yprime2)],xprime3[np.argmin(yprime3)]]
statistics.mean(list)
# Out:
# 62.645

# %%
statistics.pstdev(list)
# Out:
# 0.6200537611100111
